# %% [markdown]
# # Read the films genres

# %%
import pandas as pd

films = pd.read_csv('./dataset/movies.csv')
films.set_index('movieId', inplace=True)
films.head()
# Out:
#                                       title  \
# movieId
# 1                          Toy Story (1995)
# 2                            Jumanji (1995)
# 3                   Grumpier Old Men (1995)
# 4                  Waiting to Exhale (1995)
# 5        Father of the Bride Part II (1995)
#
#                                               genres
# movieId
# 1        Adventure|Animation|Children|Comedy|Fantasy
# 2                         Adventure|Children|Fantasy
# 3                                     Comedy|Romance
# 4                               Comedy|Drama|Romance
# 5                                             Comedy

# %% [markdown]
# # Read the Ratings

# %%
ratings = pd.read_csv('./dataset/ratings.csv')
ratings.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %% [markdown]
# <br>
# <br>
# <br>
#
# # 1. Recomending by Views

# %% [markdown]
# ### 1.1. Most viewed recently

# %%
import time
from datetime import datetime, timedelta

range_time = (datetime.now() - timedelta(days=395)).timestamp()
recent_ratings = ratings[ratings.timestamp >= range_time]

recent_ratings = recent_ratings.groupby(by="movieId").agg({"timestamp": "count"})
recent_ratings.rename(columns={"timestamp": "views"}, inplace=True)
recent_ratings.sort_values(by="views", inplace=True, ascending=False)

recent_ratings_movies = films.merge(view_mean, on="movieId", how="inner")
recent_ratings_movies.sort_values(by=["views"], ascending=False, inplace=True)

recent_ratings_movies.head(10)
# Out:
#                                              title  \
# movieId
# 356                            Forrest Gump (1994)
# 318               Shawshank Redemption, The (1994)
# 296                            Pulp Fiction (1994)
# 593               Silence of the Lambs, The (1991)
# 2571                            Matrix, The (1999)
# 260      Star Wars: Episode IV - A New Hope (1977)
# 480                           Jurassic Park (1993)
# 110                              Braveheart (1995)
# 589              Terminator 2: Judgment Day (1991)
# 527                        Schindler's List (1993)
#
#                                    genres    rating  views
# movieId
# 356              Comedy|Drama|Romance|War  4.164134    329
# 318                           Crime|Drama  4.429022    317
# 296           Comedy|Crime|Drama|Thriller  4.197068    307
# 593                 Crime|Horror|Thriller  4.161290    279
# 2571               Action|Sci-Fi|Thriller  4.192446    278
# 260               Action|Adventure|Sci-Fi  4.231076    251
# 480      Action|Adventure|Sci-Fi|Thriller  3.750000    238
# 110                      Action|Drama|War  4.031646    237
# 589                         Action|Sci-Fi  3.970982    224
# 527                             Drama|War  4.225000    220

# %% [markdown]
# ### 1.2. Top 10 movies according with the Views and Ratings

# %%
view_mean = ratings.groupby(by="movieId").agg({"rating": "mean", "timestamp": "count"})
view_mean.rename(columns={"timestamp": "views"}, inplace=True)
view_mean.sort_values(by="views", inplace=True, ascending=False)

first_recomendation = films.merge(view_mean, on="movieId", how="inner")
first_recomendation.sort_values(by=["views", "rating"], ascending=False, inplace=True)

first_recomendation.head(10)
# Out:
#                                              title  \
# movieId
# 356                            Forrest Gump (1994)
# 318               Shawshank Redemption, The (1994)
# 296                            Pulp Fiction (1994)
# 593               Silence of the Lambs, The (1991)
# 2571                            Matrix, The (1999)
# 260      Star Wars: Episode IV - A New Hope (1977)
# 480                           Jurassic Park (1993)
# 110                              Braveheart (1995)
# 589              Terminator 2: Judgment Day (1991)
# 527                        Schindler's List (1993)
#
#                                    genres    rating  views
# movieId
# 356              Comedy|Drama|Romance|War  4.164134    329
# 318                           Crime|Drama  4.429022    317
# 296           Comedy|Crime|Drama|Thriller  4.197068    307
# 593                 Crime|Horror|Thriller  4.161290    279
# 2571               Action|Sci-Fi|Thriller  4.192446    278
# 260               Action|Adventure|Sci-Fi  4.231076    251
# 480      Action|Adventure|Sci-Fi|Thriller  3.750000    238
# 110                      Action|Drama|War  4.031646    237
# 589                         Action|Sci-Fi  3.970982    224
# 527                             Drama|War  4.225000    220

# %% [markdown]
# <br>
# <br>
# <br>
#
# # 2. Same genres watched previously

# %% [markdown]
#     The variable bellow represents the movie that user already viewed

# %%
USER_WATCHING = "Comedy|Crime"

# %% [markdown]
#     Filter according with the history from the user and returns the most visualized movies of the same genres

# %%
top_same_genre = first_recomendation[[USER_WATCHING in genre for genre in first_recomendation.genres]]
top_same_genre.head(10)
# Out:
#                                        title                         genres  \
# movieId
# 106782       Wolf of Wall Street, The (2013)             Comedy|Crime|Drama
# 119145   Kingsman: The Secret Service (2015)  Action|Adventure|Comedy|Crime
# 296                      Pulp Fiction (1994)    Comedy|Crime|Drama|Thriller
# 608                             Fargo (1996)    Comedy|Crime|Drama|Thriller
# 57669                       In Bruges (2008)    Comedy|Crime|Drama|Thriller
# 61323              Burn After Reading (2008)             Comedy|Crime|Drama
# 51255                        Hot Fuzz (2007)    Action|Comedy|Crime|Mystery
#
#          rating  views
# movieId
# 106782     4.25      2
# 119145     4.25      2
# 296        5.00      1
# 608        5.00      1
# 57669      5.00      1
# 61323      5.00      1
# 51255      4.00      1

# %% [markdown]
# <br>
# <br>
# <br>
#
# ## 3. Find the most similar persons using rating

# %%
import numpy as np

movies_rating = ratings.merge(pd.DataFrame(films["title"]), on="movieId", how="inner")
movies_rating.drop(columns=["movieId", "timestamp"], inplace=True)
users = movies_rating['userId'].drop_duplicates().values

movies_rating = movies_rating.pivot_table(columns=['title'], index='userId', values='rating')

movies_rating.replace({np.nan: 0}, inplace=True)

# %% [markdown]
# #### Convert in train objects

# %%
X = movies_rating.values
y = movies_rating.index.values

# %% [markdown]
# #### Modeling

# %%
from sklearn.neighbors import NearestNeighbors

model = NearestNeighbors(n_neighbors=5, algorithm='ball_tree').fit(X)

# %% [markdown]
# <br>
# <br>
#
# #### Find near peaple

# %%
from IPython.display import HTML, display

target = 98

# Find the most similar
distances, indices = model.kneighbors([X[target]])

display(HTML("<h2>Similar people id:</h2> <h4>{}</h4>".format(str(indices[0].tolist())[1:-1])))
# Out:
# <h2>Similar people id:</h2> <h4>98, 129, 573, 144, 25</h4>

# %% [markdown]
# <br>
# <br>
#
# #### Recomending

# %%
mask = ratings.userId.isin(indices[0][1:])

# Filter the reviews by the near people
near_reviews = ratings[mask]

# Group by films
near_reviews = near_reviews.groupby("movieId").agg({"rating": "mean"})

# Remove films already viewed by the user
user_films = ratings[ratings.userId == target].movieId.values

mask = near_reviews.index.isin(user_films) == False
near_reviews = near_reviews[mask]
near_reviews.reset_index(inplace=True)

# Merge the movies
movies_views = films.merge(view_mean, on="movieId", how="inner")[["title", "genres", "views"]]
movies_views = movies_views.merge(near_reviews, on="movieId", how="inner")
recommended_movies = movies_views

# Sort descending by rating
recommended_movies.sort_values(["rating", "views"], inplace=True, ascending=False)

recommended_movies.head(20)
# Out:
#      movieId                                              title  \
# 11        50                         Usual Suspects, The (1995)
# 90      1198  Raiders of the Lost Ark (Indiana Jones and the...
# 59       590                          Dances with Wolves (1990)
# 358    58559                            Dark Knight, The (2008)
# 18       165                  Die Hard: With a Vengeance (1995)
# 29       293  Léon: The Professional (a.k.a. The Professiona...
# 146     2329                          American History X (1998)
# 237     5349                                  Spider-Man (2002)
# 171     2918                    Ferris Bueller's Day Off (1986)
# 338    48516                               Departed, The (2006)
# 12       104                               Happy Gilmore (1996)
# 384    72998                                      Avatar (2009)
# 340    48780                               Prestige, The (2006)
# 372    68157                        Inglourious Basterds (2009)
# 154     2617                                  Mummy, The (1999)
# 120     1676                           Starship Troopers (1997)
# 397    91529                      Dark Knight Rises, The (2012)
# 406    99114                            Django Unchained (2012)
# 396    89745                               Avengers, The (2012)
# 152     2542           Lock, Stock & Two Smoking Barrels (1998)
#
#                                               genres  views  rating
# 11                            Crime|Mystery|Thriller    204     5.0
# 90                                  Action|Adventure    200     5.0
# 59                           Adventure|Drama|Western    164     5.0
# 358                          Action|Crime|Drama|IMAX    149     5.0
# 18                             Action|Crime|Thriller    144     5.0
# 29                       Action|Crime|Drama|Thriller    133     5.0
# 146                                      Crime|Drama    129     5.0
# 237                 Action|Adventure|Sci-Fi|Thriller    122     5.0
# 171                                           Comedy    109     5.0
# 338                             Crime|Drama|Thriller    107     5.0
# 12                                            Comedy     99     5.0
# 384                     Action|Adventure|Sci-Fi|IMAX     97     5.0
# 340                    Drama|Mystery|Sci-Fi|Thriller     90     5.0
# 372                                 Action|Drama|War     88     5.0
# 154  Action|Adventure|Comedy|Fantasy|Horror|Thriller     87     5.0
# 120                                    Action|Sci-Fi     80     5.0
# 397                      Action|Adventure|Crime|IMAX     76     5.0
# 406                             Action|Drama|Western     71     5.0
# 396                     Action|Adventure|Sci-Fi|IMAX     69     5.0
# 152                            Comedy|Crime|Thriller     67     5.0
