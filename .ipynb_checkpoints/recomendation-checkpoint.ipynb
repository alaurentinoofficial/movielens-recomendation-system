# %% [markdown]
# # Read the films genres

# %%
import pandas as pd

films = pd.read_csv('./dataset/movies.csv')
films.set_index('movieId', inplace=True)
films.head()
# Out:
#                                       title  \
# movieId
# 1                          Toy Story (1995)
# 2                            Jumanji (1995)
# 3                   Grumpier Old Men (1995)
# 4                  Waiting to Exhale (1995)
# 5        Father of the Bride Part II (1995)
#
#                                               genres
# movieId
# 1        Adventure|Animation|Children|Comedy|Fantasy
# 2                         Adventure|Children|Fantasy
# 3                                     Comedy|Romance
# 4                               Comedy|Drama|Romance
# 5                                             Comedy

# %% [markdown]
# # Read the Ratings

# %%
ratings = pd.read_csv('./dataset/ratings.csv')
ratings.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %% [markdown]
# <br>
# <br>
# <br>
#
# # 1. Recomending by Views

# %% [markdown]
# #### Get the movie titles with the mean rating and views

# %%
import time
from datetime import datetime, timedelta

def movieRatingViews(days_ago=0):
    if days_ago != 0:
        range_time = (datetime.now() - timedelta(days=days_ago)).timestamp()
        recent_ratings = ratings[ratings.timestamp >= range_time]
    else:
        recent_ratings = ratings

    view_rating = recent_ratings.groupby(by="movieId").agg({"rating": "mean", "timestamp": "count"})
    view_rating.rename(columns={"timestamp": "views"}, inplace=True)

    movies_views = films.merge(view_rating, on="movieId", how="inner")
    movies_views.sort_values(by=["views", "rating"], ascending=False, inplace=True)
    
    return movies_views

# %% [markdown]
# ### 1.2. Top 10 movies according with the Views and Ratings

# %%
movies = movieRatingViews()
movies.sort_values(by=["views", "rating"], ascending=False, inplace=True)

movies.head(10)
# Out:
#                                              title  \
# movieId
# 356                            Forrest Gump (1994)
# 318               Shawshank Redemption, The (1994)
# 296                            Pulp Fiction (1994)
# 593               Silence of the Lambs, The (1991)
# 2571                            Matrix, The (1999)
# 260      Star Wars: Episode IV - A New Hope (1977)
# 480                           Jurassic Park (1993)
# 110                              Braveheart (1995)
# 589              Terminator 2: Judgment Day (1991)
# 527                        Schindler's List (1993)
#
#                                    genres    rating  views
# movieId
# 356              Comedy|Drama|Romance|War  4.164134    329
# 318                           Crime|Drama  4.429022    317
# 296           Comedy|Crime|Drama|Thriller  4.197068    307
# 593                 Crime|Horror|Thriller  4.161290    279
# 2571               Action|Sci-Fi|Thriller  4.192446    278
# 260               Action|Adventure|Sci-Fi  4.231076    251
# 480      Action|Adventure|Sci-Fi|Thriller  3.750000    238
# 110                      Action|Drama|War  4.031646    237
# 589                         Action|Sci-Fi  3.970982    224
# 527                             Drama|War  4.225000    220

# %% [markdown]
# ### 1.1. Most viewed recently

# %%
TARGET_DAYS_AGO = 395

# Get and filter the previous days
recent_ratings_movies = movieRatingViews(days_ago=TARGET_DAYS_AGO)
recent_ratings_movies.head(10)
# Out:
#                                        title  \
# movieId
# 58559                Dark Knight, The (2008)
# 112552                       Whiplash (2014)
# 109374      Grand Budapest Hotel, The (2014)
# 148626                 Big Short, The (2015)
# 122916                 Thor: Ragnarok (2017)
# 177765                           Coco (2017)
# 79132                       Inception (2010)
# 106782       Wolf of Wall Street, The (2013)
# 106920                            Her (2013)
# 119145   Kingsman: The Secret Service (2015)
#
#                                                   genres  rating  views
# movieId
# 58559                            Action|Crime|Drama|IMAX    5.00      2
# 112552                                             Drama    5.00      2
# 109374                                      Comedy|Drama    4.75      2
# 148626                                             Drama    4.75      2
# 122916                           Action|Adventure|Sci-Fi    4.50      2
# 177765                      Adventure|Animation|Children    4.50      2
# 79132    Action|Crime|Drama|Mystery|Sci-Fi|Thriller|IMAX    4.25      2
# 106782                                Comedy|Crime|Drama    4.25      2
# 106920                              Drama|Romance|Sci-Fi    4.25      2
# 119145                     Action|Adventure|Comedy|Crime    4.25      2

# %% [markdown]
# <br>
# <br>
# <br>
#
# # 2. Find by the the same genres

# %% [markdown]
#     The variable bellow represents the movie that user already viewed

# %%
LAST_MOVIE = "Comedy|Crime"

# %% [markdown]
#     Filter according with the history from the user and returns the most visualized movies of the same genres

# %%
def moviesByGenres(last_genre):
    movies = movieRatingViews()
    
    movies.sort_values(by=["views", "rating"], ascending=False, inplace=True)
    movies.reset_index(inplace=True)

    return movies[movies.genres == last_genre]

# %%
moviesByGenres(LAST_MOVIE).head(20)
# Out:
#       movieId                                   title        genres    rating  \
# 116      1732                Big Lebowski, The (1998)  Comedy|Crime  3.924528
# 150      2502                     Office Space (1999)  Comedy|Crime  4.090426
# 227     69122                    Hangover, The (2009)  Comedy|Crime  3.631579
# 247      1079             Fish Called Wanda, A (1988)  Comedy|Crime  3.922535
# 292      1234                       Sting, The (1973)  Comedy|Crime  3.976562
# 300      4025                Miss Congeniality (2000)  Comedy|Crime  3.054688
# 437       910                 Some Like It Hot (1959)  Comedy|Crime  4.010000
# 580      3301            Whole Nine Yards, The (2000)  Comedy|Crime  3.523810
# 615       762                       Striptease (1996)  Comedy|Crime  2.414634
# 641      2580                               Go (1999)  Comedy|Crime  3.961538
# 722      3247                       Sister Act (1992)  Comedy|Crime  3.027778
# 994      6957                        Bad Santa (2003)  Comedy|Crime  3.365385
# 1061     1125  Return of the Pink Panther, The (1975)  Comedy|Crime  3.687500
# 1071    87869                  Horrible Bosses (2011)  Comedy|Crime  3.437500
# 1169     2378                   Police Academy (1984)  Comedy|Crime  3.022727
# 1189   104211                We're the Millers (2013)  Comedy|Crime  3.738095
# 1531     2387                  Very Bad Things (1998)  Comedy|Crime  3.437500
# 1603    97306                Seven Psychopaths (2012)  Comedy|Crime  3.466667
# 1735     7367                 Ladykillers, The (2004)  Comedy|Crime  2.571429
# 1821     4677                   Turner & Hooch (1989)  Comedy|Crime  3.038462
#
#       views
# 116     106
# 150      94
# 227      76
# 247      71
# 292      64
# 300      64
# 437      50
# 580      42
# 615      41
# 641      39
# 722      36
# 994      26
# 1061     24
# 1071     24
# 1169     22
# 1189     21
# 1531     16
# 1603     15
# 1735     14
# 1821     13

# %% [markdown]
# <br>
# <br>
# <br>
#
# ## 3. Find the most similar persons using rating

# %% [markdown]
# #### Create a method to get the near people based on the watched films

# %%
import numpy as np
from sklearn.neighbors import NearestNeighbors

def findNearPersons(user, n_people=5):
    #####################
    # EXTRACT DUMMIES
    movies_rating = ratings.merge(pd.DataFrame(films["title"]), on="movieId", how="inner")
    movies_rating.drop(columns=["movieId", "timestamp"], inplace=True)
    users = movies_rating['userId'].drop_duplicates().values

    movies_rating = movies_rating.pivot_table(columns=['title'], index='userId', values='rating')

    movies_rating.replace({np.nan: 0}, inplace=True)
    #####################
    
    X = movies_rating.values
    
    #####################
    # Create a model KNN
    model = NearestNeighbors(n_neighbors=n_people, algorithm='ball_tree').fit(X)
    #####################
    
    # Get the near people
    distances, indices = model.kneighbors([X[movies_rating.index.get_loc(user)]])
    
    return (distances[0], indices[0],)

# %%
def moviesByNearPeople(user, n_people=5):
    # Find the people in commom
    distances, indices = findNearPersons(TARGET_USER, n_people=n_people)
    
    # Get the movies
    movies = movieRatingViews()
    movies.reset_index(inplace=True)

    # Filter the reviews by the near people
    mask = ratings.userId.isin(indices)
    moviesId = ratings[mask]

    # Remove the duplicates
    moviesId = moviesId.movieId.drop_duplicates()

    # Remove films already viewed by the user
    user_films = ratings[ratings.userId == TARGET_USER].movieId.values # Get the user movies id
    mask = moviesId.isin(user_films) == False # Check if not exists in user_films
    moviesId = moviesId[mask]


    # Filtering and sort the movies
    return movies[movies.movieId.isin(moviesId.values)].sort_values(by=["views", "rating"], ascending=False)

# %%
from IPython.display import display, HTML

# Define the actual user
TARGET_USER = 98
display(HTML('<h3>Target: <i>{}</i><h3/>'.format(TARGET_USER)))

# Near people
_, indices = findNearPersons(TARGET_USER)
display(HTML('<h3>Near people: <i>{}</i><h3/>'.format(indices)))
# Out:
# <h3>Target: <i>98</i><h3/>
# <h3>Near people: <i>[ 97 441 292 507 328]</i><h3/>

# %%
moviesByNearPeople(user=TARGET_USER).head(20)
# Out:
#     movieId                                              title  \
# 1       318                   Shawshank Redemption, The (1994)
# 2       296                                Pulp Fiction (1994)
# 4      2571                                 Matrix, The (1999)
# 5       260          Star Wars: Episode IV - A New Hope (1977)
# 6       480                               Jurassic Park (1993)
# 7       110                                  Braveheart (1995)
# 8       589                  Terminator 2: Judgment Day (1991)
# 9       527                            Schindler's List (1993)
# 10     2959                                  Fight Club (1999)
# 12     1196  Star Wars: Episode V - The Empire Strikes Back...
# 13       50                         Usual Suspects, The (1995)
# 15       47                        Seven (a.k.a. Se7en) (1995)
# 16      780               Independence Day (a.k.a. ID4) (1996)
# 17      150                                   Apollo 13 (1995)
# 18     1198  Raiders of the Lost Ark (Indiana Jones and the...
# 19     4993  Lord of the Rings: The Fellowship of the Ring,...
# 20     1210  Star Wars: Episode VI - Return of the Jedi (1983)
# 22      457                               Fugitive, The (1993)
# 23      592                                      Batman (1989)
# 24     2028                         Saving Private Ryan (1998)
#
#                               genres    rating  views
# 1                        Crime|Drama  4.429022    317
# 2        Comedy|Crime|Drama|Thriller  4.197068    307
# 4             Action|Sci-Fi|Thriller  4.192446    278
# 5            Action|Adventure|Sci-Fi  4.231076    251
# 6   Action|Adventure|Sci-Fi|Thriller  3.750000    238
# 7                   Action|Drama|War  4.031646    237
# 8                      Action|Sci-Fi  3.970982    224
# 9                          Drama|War  4.225000    220
# 10       Action|Crime|Drama|Thriller  4.272936    218
# 12           Action|Adventure|Sci-Fi  4.215640    211
# 13            Crime|Mystery|Thriller  4.237745    204
# 15                  Mystery|Thriller  3.975369    203
# 16  Action|Adventure|Sci-Fi|Thriller  3.445545    202
# 17              Adventure|Drama|IMAX  3.845771    201
# 18                  Action|Adventure  4.207500    200
# 19                 Adventure|Fantasy  4.106061    198
# 20           Action|Adventure|Sci-Fi  4.137755    196
# 22                          Thriller  3.992105    190
# 23             Action|Crime|Thriller  3.428571    189
# 24                  Action|Drama|War  4.146277    188

# %% [markdown]
# <br>
# <br>
#
#
# # 4. Recomending after the watch some movie
#
# > To solve that problem i'm considering the rating dataset work like a history of watched movies

# %% [markdown]
# #### Configuring

# %%
from IPython.display import display, HTML

# Proposal film
TARGET_MOVIE = 296

movie_name = films[films.index == TARGET_MOVIE].title.iloc[0]
display(HTML('<h3>Target: <i>{}</i><h3/>'.format(films[films.index == TARGET_MOVIE].title.iloc[0])))
# Out:
# <h3>Target: <i>Pulp Fiction (1994)</i><h3/>

# %% [markdown]
# #### Search the next movie

# %%
import pandas as pd
from collections import Counter

def peopleWatchedAfter(target):
    ratings.sort_values(by="timestamp", inplace=True)

    # Create a counter
    movies = Counter()

    # Find the user witch already watched
    users = ratings[ratings.movieId == TARGET_MOVIE].userId.values

    # Pass by each user
    for user in users:
        # Find the movies
        user_movies = ratings[ratings.userId == user].movieId.values

        # Find the target movie and sum at counter
        for i in range(len(user_movies)):
            if user_movies[i] == target:
                try:
                    movies[user_movies[i + 1]] += 1
                except IndexError:
                    continue
    
    next_movies = pd.DataFrame(list(movies.items()), columns=["movieId", "views"])
    next_movies.sort_values(by="views", ascending=False, inplace=True)
    next_movies.reset_index(drop=True, inplace=True)

    movies = movieRatingViews()
    
    return next_movies.join(movies[["rating", "title"]], on="movieId", how="inner")

# %%
watch_next_movies = peopleWatchedAfter(TARGET_MOVIE)
watch_next_movies.sort_values(by=["views", "rating"], ascending=False, inplace=True)
watch_next_movies.head(20)
# Out:
#     movieId  views    rating  \
# 0       380     21  3.497191
# 1       150     19  3.845771
# 2       356     17  4.164134
# 3       593     12  4.161290
# 4       592      9  3.428571
# 6      2959      6  4.272936
# 5      1213      6  4.250000
# 7      1089      6  4.202290
# 8       344      6  3.040373
# 9        50      5  4.237745
# 10      527      5  4.225000
# 17    58559      4  4.238255
# 12     2329      4  4.217054
# 11      293      4  4.018797
# 16      590      4  3.835366
# 15      588      4  3.792350
# 14      349      4  3.604545
# 13      165      4  3.555556
# 20    48516      3  4.252336
# 18     2571      3  4.192446
#
#                                                 title
# 0                                    True Lies (1994)
# 1                                    Apollo 13 (1995)
# 2                                 Forrest Gump (1994)
# 3                    Silence of the Lambs, The (1991)
# 4                                       Batman (1989)
# 6                                   Fight Club (1999)
# 5                                   Goodfellas (1990)
# 7                               Reservoir Dogs (1992)
# 8                   Ace Ventura: Pet Detective (1994)
# 9                          Usual Suspects, The (1995)
# 10                            Schindler's List (1993)
# 17                            Dark Knight, The (2008)
# 12                          American History X (1998)
# 11  Léon: The Professional (a.k.a. The Professiona...
# 16                          Dances with Wolves (1990)
# 15                                     Aladdin (1992)
# 14                    Clear and Present Danger (1994)
# 13                  Die Hard: With a Vengeance (1995)
# 20                               Departed, The (2006)
# 18                                 Matrix, The (1999)

# %% [markdown]
# <br>
# <br>
#
# # 5. Watch the movies again

# %% [markdown]
# #### Configuring

# %%
from IPython.display import display, HTML

# Proposal film
TARGET_USER = 98

display(HTML('<h3>User Target: <i>{}</i><h3/>'.format(TARGET_USER)))
# Out:
# <h3>User Target: <i>98</i><h3/>

# %%
def moviesWatchAgain(user, batch_size=10, selection_size=None):
    already_watched = ratings[ratings.userId == user][["movieId", "rating", "timestamp"]]
    already_watched.sort_values(by=["rating"], ascending=False, inplace=True) # Chorological sort
    
    movies = movieRatingViews()[["title"]]
    
    movies = already_watched.join(movies, on="movieId", how="inner")
    movies.reset_index(drop=True, inplace=True)
    
    selection = movies[movies.index < (batch_size * 2 if selection_size is None else selection_size)]
    
    batch_size = min(batch_size, selection.shape[0])
    
    return selection.sample(batch_size)

# %%
moviesWatchAgain(TARGET_USER, batch_size=20)
# Out:
#     movieId  rating   timestamp  \
# 15    74458     5.0  1532457910
# 39    81847     4.5  1532457483
# 6      1197     5.0  1532457921
# 29     1214     4.5  1532457890
# 12    50872     5.0  1532458002
# 5      1258     5.0  1532457919
# 35   168250     4.5  1532457987
# 10   122916     5.0  1532457746
# 22    97921     5.0  1532457833
# 36   104841     4.5  1532457992
# 25    46578     5.0  1532458168
# 3    187593     5.0  1532457913
# 13    47099     5.0  1532458013
# 27   122912     5.0  1532457477
# 9     60126     5.0  1532457590
# 37     5444     4.5  1532457999
# 21    38038     5.0  1532458294
# 8      1036     5.0  1532457796
# 24     4306     5.0  1532457782
# 7      8961     5.0  1532457742
#
#                                                 title
# 15                              Shutter Island (2010)
# 39                                     Tangled (2010)
# 6                          Princess Bride, The (1987)
# 29                                       Alien (1979)
# 12                                 Ratatouille (2007)
# 5                                 Shining, The (1980)
# 35                                     Get Out (2017)
# 10                              Thor: Ragnarok (2017)
# 22                     Silver Linings Playbook (2012)
# 36                                     Gravity (2013)
# 25                        Little Miss Sunshine (2006)
# 3                                   Deadpool 2 (2018)
# 13                   Pursuit of Happyness, The (2006)
# 27             Avengers: Infinity War - Part I (2018)
# 9                                    Get Smart (2008)
# 37                               Lilo & Stitch (2002)
# 21  Wallace & Gromit in The Curse of the Were-Rabb...
# 8                                     Die Hard (1988)
# 24                                       Shrek (2001)
# 7                             Incredibles, The (2004)
